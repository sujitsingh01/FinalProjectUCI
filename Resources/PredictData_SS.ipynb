# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
file ='data.csv'
df = pd.read_csv(file)
datat=df[["product_group","cosmos_cement_sp","cosmos_silica_error", "felt_speed","feed_temperature", "mor_filled"]]
filter_product = datat['product_group']=='Backer'
data=datat[filter_product]
data[["cosmos_cement_sp","cosmos_silica_error", "felt_speed","feed_temperature", "mor_filled"]]
# Out:
#       cosmos_cement_sp  cosmos_silica_error  felt_speed  feed_temperature  \
# 2                370.0               0.2813     367.458           115.041
# 3                370.0               0.2813     367.458           115.041
# 4                370.0               0.7912     364.765           115.015
# 5                370.0               0.7912     364.765           115.015
# 8                370.0              -0.9201     361.758           115.053
# 9                370.0              -0.9201     361.758           115.053
# 10               370.0               0.4410     361.577           115.014
# 11               370.0               0.4410     361.577           115.014
# 12               370.0               0.1551     361.604           114.949
# 13               370.0               0.1551     361.604           114.949
# 14               370.0               0.5731     361.562           115.033
# 15               370.0               0.5731     361.562           115.033
# ...

# %%
X1 = data.drop("product_group", axis=1)
X = X1.drop("mor_filled", axis=1)
y = data["mor_filled"]
print(X.shape, y.shape)
# Out:
# (1656, 4) (1656,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# C:\Users\SujitS.JHBP\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=5, activation='relu', input_dim=4))
model.add(Dense(units=5, activation='relu'))
model.add(Dense(units=1, activation='softmax'))

# %%
# Compile and fit the model

model.compile(optimizer='adam', loss='mse')

model.fit(
    X_train,
    y_train,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
#  - 0s - loss: 51.8772
# Epoch 2/60
#  - 0s - loss: 51.8772
# Epoch 3/60
#  - 0s - loss: 51.8772
# Epoch 4/60
#  - 0s - loss: 51.8772
# Epoch 5/60
#  - 0s - loss: 51.8772
# Epoch 6/60
#  - 0s - loss: 51.8772
# Epoch 7/60
#  - 0s - loss: 51.8772
# Epoch 8/60
#  - 0s - loss: 51.8772
# Epoch 9/60
#  - 0s - loss: 51.8772
# Epoch 10/60
#  - 0s - loss: 51.8772
# Epoch 11/60
#  - 0s - loss: 51.8772
# Epoch 12/60
#  - 0s - loss: 51.8772
# Epoch 13/60
#  - 0s - loss: 51.8772
# Epoch 14/60
#  - 0s - loss: 51.8772
# Epoch 15/60
#  - 0s - loss: 51.8772
# Epoch 16/60
#  - 0s - loss: 51.8772
# Epoch 17/60
#  - 0s - loss: 51.8772
# Epoch 18/60
#  - 0s - loss: 51.8772
# Epoch 19/60
#  - 0s - loss: 51.8772
# Epoch 20/60
#  - 0s - loss: 51.8772
# Epoch 21/60
#  - 0s - loss: 51.8772
# Epoch 22/60
#  - 0s - loss: 51.8772
# Epoch 23/60
#  - 0s - loss: 51.8772
# Epoch 24/60
#  - 0s - loss: 51.8772
# Epoch 25/60
#  - 0s - loss: 51.8772
# Epoch 26/60
#  - 0s - loss: 51.8772
# Epoch 27/60
# ...

# %%
encoded_predictions = model.predict_classes(X_test[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:1])}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-16ac6f34f580> in <module>()
#       1 encoded_predictions = model.predict_classes(X_test[:5])
# ----> 2 prediction_labels = label_encoder.inverse_transform(encoded_predictions)
#       3 print(f"Predicted classes: {prediction_labels}")
#       4 print(f"Actual Labels: {list(y_test[:1])}")
#
# NameError: name 'label_encoder' is not defined
